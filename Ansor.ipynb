# %% [markdown]
# # Auto-scheduling a Convolution Layer for GPU

# %% [markdown]
# This is a tutorial on how to use the auto-scheduler for GPUs.
#
# Different from the template-based [autotvm](https://tvm.apache.org/docs/tutorials/index.html#tutorials-autotvm-sec)
# which relies on manual templates to define the search space, the auto-scheduler does not require any templates.
# Users only need to write the computation declaration without any schedule commands or templates.
# The auto-scheduler can automatically generate a large search space and
# find a good schedule in the space.
#
# We use a convolution layer as an example in this tutorial.

# %%
import os

import numpy as np
import tvm
from tvm import te, auto_scheduler, topi
from tvm.topi.testing import conv2d_nchw_python

# %% [markdown]
# ## Define the computation

# %% [markdown]
# To begin with, let us define the computation of a convolution layer. The function should return the list of input/output tensors. From these tensors, the auto-scheduler can get the whole computational graph.

# %%
@auto_scheduler.register_workload
def conv2d_layer(N, H, W, CO, CI, KH, KW, stride, padding):
    data = te.placeholder((N, CI, H, W), name="data")
    kernel = te.placeholder((CO, CI, KH, KW), name="kernel")
    bias = te.placeholder((1, CO, 1, 1), name="bias")
    conv = topi.nn.conv2d_nchw(data, kernel, stride, padding, dilation=1, out_dtype="float32")
    out = topi.nn.relu(conv + bias)
    return [data, kernel, bias, out]

# %% [markdown]
# ## Create the search task

# %% [markdown]
# We then create a search task for the last convolution layer in the resnet.

# %%
target = tvm.target.Target("cuda")

# Use the last layer in ResNet-50
N, H, W, CO, CI, KH, KW, strides, padding = 1, 7, 7, 512, 512, 3, 3, (1, 1), (1, 1)
task = auto_scheduler.SearchTask(
    func=conv2d_layer, args=(N, H, W, CO, CI, KH, KW, strides, padding), target=target
)

# Inspect the computational graph
print("Computational DAG:")
print(task.compute_dag)
# Out:
# Computational DAG:
# data = PLACEHOLDER [1, 512, 7, 7]
# pad_temp(i0, i1, i2, i3) = tir.if_then_else(((((i2 >= 1) && (i2 < 8)) && (i3 >= 1)) && (i3 < 8)), data[i0, i1, (i2 - 1), (i3 - 1)], 0f)
# kernel = PLACEHOLDER [512, 512, 3, 3]
# compute(nn, ff, yy, xx) += (pad_temp[nn, rc, (yy + ry), (xx + rx)]*kernel[ff, rc, ry, rx])
# bias = PLACEHOLDER [1, 512, 1, 1]
# T_add(ax0, ax1, ax2, ax3) = (compute[ax0, ax1, ax2, ax3] + bias[ax0, ax1, 0, 0])
# compute(i0, i1, i2, i3) = max(T_add[i0, i1, i2, i3], 0f)

# %% [markdown]
# Next, we set parameters for the auto-scheduler. These parameters
# mainly specify how we do the measurement during the search.
#
# - `measure_ctx` launches a different process for measurement to
# provide isolation. It can protect the master process from GPU crashes
# during measurement and avoid other runtime conflicts.
# - `min_repeat_ms` defines the minimum duration of one "repeat" in every measurement.
# This can warmup the GPU, which is necessary to get accurate measurement results.
# Typically, we recommend a value >= 300 ms.
# - `num_measure_trials` is the number of measurement trials we can use during the search.
# We only make 10 trials in this tutorial for a fast demonstration. In practice, 1000 is a
# good value for the search to converge. You can do more trials according to your time budget.
# - In addition, we use `RecordToFile` to dump measurement records into a file *conv2d.json*.
# The measurement records can be used to query the history best, resume the search,
# and do more analyses later.
# - see [`auto_scheduler.TuningOptions`](https://tvm.apache.org/docs/api/python/auto_scheduler.html#tvm.auto_scheduler.TuningOptions),
# [`auto_scheduler.LocalRPCMeasureContext`](https://tvm.apache.org/docs/api/python/auto_scheduler.html#tvm.auto_scheduler.LocalRPCMeasureContext)
# for more parameters.

# %%
log_file = "conv2d.json"
measure_ctx = auto_scheduler.LocalRPCMeasureContext(min_repeat_ms=300)
tune_option = auto_scheduler.TuningOptions(
    num_measure_trials=10,  # change this to 1000 to achieve the best performance
    runner=measure_ctx.runner,
    measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    verbose=2,
)
# Out:
# Get devices for measurement successfully!

# %% [markdown]
# ## Run the search

# %% [markdown]
# Now we get all inputs ready. Pretty simple, isn’t it? We can kick off the search and let the auto-scheduler do its magic. After some measurement trials, we can load the best schedule from the log file and apply it.

# %%
# Run auto-tuning (search)
task.tune(tune_option)
# Apply the best schedule
sch, args = task.apply_best(log_file)

# Kill the measurement process
del measure_ctx

# %% [markdown]
# We can lower the schedule to see the IR after auto-scheduling. The auto-scheduler correctly performs optimizations including multi-level tiling, cooperative fetching, unrolling and operator fusion.

# %%
print("Lowered TIR:")
print(tvm.lower(sch, args, simple_mode=True))
# Out:
# Lowered TIR:
# primfn(data_1: handle, kernel_1: handle, bias_1: handle, compute_1: handle) -> ()
#   attr = {"from_legacy_te_schedule": True, "global_symbol": "main", "tir.noalias": True}
#   buffers = {data: Buffer(data_2: Pointer(float32), float32, [1, 512, 7, 7], []),
#              compute: Buffer(compute_2: Pointer(float32), float32, [1, 512, 7, 7], []),
#              bias: Buffer(bias_2: Pointer(float32), float32, [1, 512, 1, 1], []),
#              kernel: Buffer(kernel_2: Pointer(float32), float32, [512, 512, 3, 3], [])}
#   buffer_map = {data_1: data, kernel_1: kernel, bias_1: bias, compute_1: compute} {
#   attr [IterVar(blockIdx.x: int32, (nullptr), "ThreadIndex", "blockIdx.x")] "thread_extent" = 16;
#   allocate(compute_3: Pointer(local float32), float32, [8]), storage_scope = local;
#   allocate(pad_temp.shared: Pointer(shared float32), float32, [1008]), storage_scope = shared;
#   allocate(kernel.shared: Pointer(shared float32), float32, [1536]), storage_scope = shared;
#   attr [IterVar(threadIdx.x: int32, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196 {
#     compute_3[0] = 0f32
#     compute_3[1] = 0f32
#     compute_3[2] = 0f32
#     compute_3[3] = 0f32
#     compute_3[4] = 0f32
#     compute_3[5] = 0f32
#     compute_3[6] = 0f32
#     compute_3[7] = 0f32
#     for (rc.outer.outer: int32, 0, 32) {
#       for (ry.outer.outer: int32, 0, 3) {
#         attr [IterVar(threadIdx.x_1: int32, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196 {
#           pad_temp.shared[(threadIdx.x_1*4)] = @tir.if_then_else(((((1 <= (floordiv(floormod((threadIdx.x_1*4), 63), 9) + ry.outer.outer)) && ((floordiv(floormod((threadIdx.x_1*4), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod((threadIdx.x_1*4), 9))) && (floormod((threadIdx.x_1*4), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv((threadIdx.x_1*4), 9)*7)) + (ry.outer.outer*7)) + floormod((threadIdx.x_1*4), 9)) - 8)], 0f32, dtype=float32)
#           pad_temp.shared[((threadIdx.x_1*4) + 1)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 1), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 1), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 1), 9))) && (floormod(((threadIdx.x_1*4) + 1), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 1), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 1), 9)) - 8)], 0f32, dtype=float32)
#           pad_temp.shared[((threadIdx.x_1*4) + 2)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 2), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 2), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 2), 9))) && (floormod(((threadIdx.x_1*4) + 2), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 2), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 2), 9)) - 8)], 0f32, dtype=float32)
#           pad_temp.shared[((threadIdx.x_1*4) + 3)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 3), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 3), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 3), 9))) && (floormod(((threadIdx.x_1*4) + 3), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 3), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 3), 9)) - 8)], 0f32, dtype=float32)
#         }
#         attr [IterVar(threadIdx.x_1, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196 {
#           if @tir.likely((threadIdx.x_1 < 56), dtype=bool) {
#             pad_temp.shared[((threadIdx.x_1*4) + 784)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 28), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 28), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 1), 9))) && (floormod(((threadIdx.x_1*4) + 1), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 784), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 1), 9)) - 8)], 0f32, dtype=float32)
#           }
#           if @tir.likely(((threadIdx.x_1*4) < 223), dtype=bool) {
#             if @tir.likely((threadIdx.x_1 < 56), dtype=bool) {
#               pad_temp.shared[((threadIdx.x_1*4) + 785)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 29), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 29), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 2), 9))) && (floormod(((threadIdx.x_1*4) + 2), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 785), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 2), 9)) - 8)], 0f32, dtype=float32)
#             }
#           }
#           if @tir.likely(((threadIdx.x_1*4) < 222), dtype=bool) {
#             if @tir.likely((threadIdx.x_1 < 56), dtype=bool) {
#               pad_temp.shared[((threadIdx.x_1*4) + 786)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 30), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 30), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 3), 9))) && (floormod(((threadIdx.x_1*4) + 3), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 786), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 3), 9)) - 8)], 0f32, dtype=float32)
#             }
#           }
#           if @tir.likely(((threadIdx.x_1*4) < 221), dtype=bool) {
#             if @tir.likely((threadIdx.x_1 < 56), dtype=bool) {
#               pad_temp.shared[((threadIdx.x_1*4) + 787)] = @tir.if_then_else(((((1 <= (floordiv(floormod(((threadIdx.x_1*4) + 31), 63), 9) + ry.outer.outer)) && ((floordiv(floormod(((threadIdx.x_1*4) + 31), 63), 9) + ry.outer.outer) < 8)) && (1 <= floormod(((threadIdx.x_1*4) + 4), 9))) && (floormod(((threadIdx.x_1*4) + 4), 9) < 8)), (float32*)data_2[(((((rc.outer.outer*784) + (floordiv(((threadIdx.x_1*4) + 787), 9)*7)) + (ry.outer.outer*7)) + floormod(((threadIdx.x_1*4) + 4), 9)) - 8)], 0f32, dtype=float32)
#             }
#           }
#         }
#         attr [IterVar(threadIdx.x_2: int32, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[threadIdx.x_2] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv(threadIdx.x_2, 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod(threadIdx.x_2, 48), 3)*9)) + (ry.outer.outer*3)) + floormod(threadIdx.x_2, 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[(threadIdx.x_2 + 196)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 196), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 4), 48), 3)*9)) + (ry.outer.outer*3)) + floormod((threadIdx.x_2 + 1), 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[(threadIdx.x_2 + 392)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 392), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 8), 48), 3)*9)) + (ry.outer.outer*3)) + floormod((threadIdx.x_2 + 2), 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[(threadIdx.x_2 + 588)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 588), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 12), 48), 3)*9)) + (ry.outer.outer*3)) + floormod(threadIdx.x_2, 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[(threadIdx.x_2 + 784)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 784), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 16), 48), 3)*9)) + (ry.outer.outer*3)) + floormod((threadIdx.x_2 + 1), 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[(threadIdx.x_2 + 980)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 980), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 20), 48), 3)*9)) + (ry.outer.outer*3)) + floormod((threadIdx.x_2 + 2), 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         kernel.shared[(threadIdx.x_2 + 1176)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 1176), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 24), 48), 3)*9)) + (ry.outer.outer*3)) + floormod(threadIdx.x_2, 3))]
#         attr [IterVar(threadIdx.x_2, (nullptr), "ThreadIndex", "threadIdx.x")] "thread_extent" = 196;
#         if @tir.likely((threadIdx.x_2 < 164), dtype=bool) {
#           kernel.shared[(threadIdx.x_2 + 1372)] = (float32*)kernel_2[((((((blockIdx.x*147456) + (floordiv((threadIdx.x_2 + 1372), 48)*4608)) + (rc.outer.outer*144)) + (floordiv(floormod((threadIdx.x_2 + 28), 48), 3)*9)) + (ry.outer.outer*3)) + floormod((threadIdx.x_2 + 1), 3))]
#         }
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[(floordiv(threadIdx.x, 49)*48)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 192)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 384)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 576)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 768)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 960)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1152)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7))]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1344)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 193)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 385)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 577)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 769)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 961)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1153)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 1)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1345)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 2)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 194)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 386)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 578)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 770)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 962)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1154)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 2)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1346)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 3)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 195)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 387)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 579)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 771)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 963)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1155)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 63)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1347)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 4)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 196)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 388)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 580)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 772)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 964)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1156)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 64)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1348)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 5)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 197)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 389)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 581)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 773)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 965)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1157)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 65)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1349)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 6)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 198)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 390)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 582)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 774)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 966)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1158)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 126)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1350)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 7)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 199)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 391)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 583)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 775)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 967)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1159)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 127)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1351)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 8)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 200)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 392)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 584)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 776)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 968)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1160)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 128)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1352)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 9)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 201)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 393)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 585)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 777)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 969)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1161)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 189)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1353)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 10)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 202)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 394)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 586)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 778)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 970)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1162)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 190)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1354)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 11)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 203)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 395)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 587)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 779)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 971)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1163)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 191)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1355)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 12)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 204)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 396)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 588)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 780)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 972)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1164)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 252)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1356)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 13)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 205)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 397)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 589)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 781)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 973)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1165)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 253)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1357)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 14)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 206)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 398)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 590)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 782)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 974)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1166)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 254)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1358)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 15)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 207)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 399)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 591)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 783)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 975)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1167)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 315)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1359)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 16)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 208)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 400)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 592)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 784)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 976)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1168)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 316)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1360)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 17)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 209)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 401)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 593)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 785)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 977)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1169)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 317)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1361)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 18)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 210)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 402)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 594)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 786)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 978)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1170)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 378)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1362)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 19)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 211)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 403)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 595)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 787)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 979)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1171)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 379)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1363)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 20)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 212)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 404)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 596)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 788)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 980)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1172)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 380)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1364)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 441)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 21)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 441)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 213)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 441)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 405)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 441)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 597)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 441)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 789)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 441)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 981)]))
# ...
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 819)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1383)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 40)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 232)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 424)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 616)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 808)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1000)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1192)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 820)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1384)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 41)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 233)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 425)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 617)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 809)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1001)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1193)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 821)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1385)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 42)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 234)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 426)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 618)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 810)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1002)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1194)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 882)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1386)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 43)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 235)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 427)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 619)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 811)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1003)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1195)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 883)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1387)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 44)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 236)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 428)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 620)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 812)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1004)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1196)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 884)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1388)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 45)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 237)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 429)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 621)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 813)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1005)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1197)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 945)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1389)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 46)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 238)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 430)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 622)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 814)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1006)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1198)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 946)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1390)]))
#         compute_3[0] = ((float32*)compute_3[0] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 47)]))
#         compute_3[1] = ((float32*)compute_3[1] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 239)]))
#         compute_3[2] = ((float32*)compute_3[2] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 431)]))
#         compute_3[3] = ((float32*)compute_3[3] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 623)]))
#         compute_3[4] = ((float32*)compute_3[4] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 815)]))
#         compute_3[5] = ((float32*)compute_3[5] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1007)]))
#         compute_3[6] = ((float32*)compute_3[6] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1199)]))
#         compute_3[7] = ((float32*)compute_3[7] + ((float32*)pad_temp.shared[(((floordiv(floormod(threadIdx.x, 49), 7)*9) + floormod(threadIdx.x, 7)) + 947)]*(float32*)kernel.shared[((floordiv(threadIdx.x, 49)*48) + 1391)]))
#       }
#     }
#     compute_2[((blockIdx.x*1568) + threadIdx.x)] = max(((float32*)compute_3[0] + (float32*)bias_2[((blockIdx.x*32) + floordiv(threadIdx.x, 49))]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 196)] = max(((float32*)compute_3[1] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 4)]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 392)] = max(((float32*)compute_3[2] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 8)]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 588)] = max(((float32*)compute_3[3] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 12)]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 784)] = max(((float32*)compute_3[4] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 16)]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 980)] = max(((float32*)compute_3[5] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 20)]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 1176)] = max(((float32*)compute_3[6] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 24)]), 0f32)
#     compute_2[(((blockIdx.x*1568) + threadIdx.x) + 1372)] = max(((float32*)compute_3[7] + (float32*)bias_2[(((blockIdx.x*32) + floordiv(threadIdx.x, 49)) + 28)]), 0f32)
#   }
# }

# %% [markdown]
# ## Check correctness and evaluate performance

# %% [markdown]
# We build the binary and check its correctness and performance.

# %%
func = tvm.build(sch, args, target)

# Check correctness
data_np = np.random.uniform(size=(N, CI, H, W)).astype(np.float32)
weight_np = np.random.uniform(size=(CO, CI, KH, KW)).astype(np.float32)
bias_np = np.random.uniform(size=(1, CO, 1, 1)).astype(np.float32)
conv_np = conv2d_nchw_python(data_np, weight_np, strides, padding)
out_np = np.maximum(conv_np + bias_np, 0.0)

dev = tvm.cuda()
data_tvm = tvm.nd.array(data_np, device=dev)
weight_tvm = tvm.nd.array(weight_np, device=dev)
bias_tvm = tvm.nd.array(bias_np, device=dev)
out_tvm = tvm.nd.empty(out_np.shape, device=dev)
func(data_tvm, weight_tvm, bias_tvm, out_tvm)

# Check results
np.testing.assert_allclose(out_np, out_tvm.numpy(), rtol=1e-3)

# Evaluate execution time
evaluator = func.time_evaluator(func.entry_name, dev, min_repeat_ms=500)
print(
    "Execution time of this operator: %.3f ms"
    % (np.median(evaluator(data_tvm, weight_tvm, bias_tvm, out_tvm).results) * 1000)
)
# Out:
# Execution time of this operator: 0.183 ms

# %% [markdown]
# ## Using the record file

# %% [markdown]
# During the search, all measurement records are dumped into the record file “conv2d.json”. The measurement records can be used to re-apply search results, resume the search, and perform other analyses.
#
# Here is an example where we load the best schedule from a file, print the equivalent python schedule API and CUDA source code. They can be used for debugging and learning the behavior of the auto-scheduler.

# %%
print("Equivalent python schedule:")
print(task.print_best(log_file, print_mode="schedule"))

print("CUDA source code:")
print(task.print_best(log_file, print_mode="cuda"))
# Out:
# Equivalent python schedule:
# pad_temp_i0, pad_temp_i1, pad_temp_i2, pad_temp_i3 = tuple(pad_temp.op.axis) + tuple(pad_temp.op.reduce_axis)
# compute_nn, compute_ff, compute_yy, compute_xx, compute_rc, compute_ry, compute_rx = tuple(compute.op.axis) + tuple(compute.op.reduce_axis)
# T_add_ax0, T_add_ax1, T_add_ax2, T_add_ax3 = tuple(T_add.op.axis) + tuple(T_add.op.reduce_axis)
# compute_i0, compute_i1, compute_i2, compute_i3 = tuple(compute.op.axis) + tuple(compute.op.reduce_axis)
# s[T_add].compute_inline()
# compute_nn_o_i, compute_nn_i = s[compute].split(compute_nn, factor=1)
# compute_nn_o_o_i, compute_nn_o_i = s[compute].split(compute_nn_o_i, factor=1)
# compute_nn_o_o_o_i, compute_nn_o_o_i = s[compute].split(compute_nn_o_o_i, factor=1)
# compute_nn_o_o_o_o, compute_nn_o_o_o_i = s[compute].split(compute_nn_o_o_o_i, factor=1)
# compute_ff_o_i, compute_ff_i = s[compute].split(compute_ff, factor=1)
# compute_ff_o_o_i, compute_ff_o_i = s[compute].split(compute_ff_o_i, factor=1)
# compute_ff_o_o_o_i, compute_ff_o_o_i = s[compute].split(compute_ff_o_o_i, factor=4)
# compute_ff_o_o_o_o, compute_ff_o_o_o_i = s[compute].split(compute_ff_o_o_o_i, factor=8)
# compute_yy_o_i, compute_yy_i = s[compute].split(compute_yy, factor=1)
# compute_yy_o_o_i, compute_yy_o_i = s[compute].split(compute_yy_o_i, factor=1)
# compute_yy_o_o_o_i, compute_yy_o_o_i = s[compute].split(compute_yy_o_o_i, factor=7)
# compute_yy_o_o_o_o, compute_yy_o_o_o_i = s[compute].split(compute_yy_o_o_o_i, factor=1)
# compute_xx_o_i, compute_xx_i = s[compute].split(compute_xx, factor=1)
# compute_xx_o_o_i, compute_xx_o_i = s[compute].split(compute_xx_o_i, factor=1)
# compute_xx_o_o_o_i, compute_xx_o_o_i = s[compute].split(compute_xx_o_o_i, factor=7)
# compute_xx_o_o_o_o, compute_xx_o_o_o_i = s[compute].split(compute_xx_o_o_o_i, factor=1)
# compute_rc_o_i, compute_rc_i = s[compute].split(compute_rc, factor=1)
# compute_rc_o_o, compute_rc_o_i = s[compute].split(compute_rc_o_i, factor=16)
# compute_ry_o_i, compute_ry_i = s[compute].split(compute_ry, factor=1)
# compute_ry_o_o, compute_ry_o_i = s[compute].split(compute_ry_o_i, factor=1)
# compute_rx_o_i, compute_rx_i = s[compute].split(compute_rx, factor=3)
# compute_rx_o_o, compute_rx_o_i = s[compute].split(compute_rx_o_i, factor=1)
# s[compute].reorder(compute_nn_o_o_o_o, compute_ff_o_o_o_o, compute_yy_o_o_o_o, compute_xx_o_o_o_o, compute_nn_o_o_o_i, compute_ff_o_o_o_i, compute_yy_o_o_o_i, compute_xx_o_o_o_i, compute_nn_o_o_i, compute_ff_o_o_i, compute_yy_o_o_i, compute_xx_o_o_i, compute_rc_o_o, compute_ry_o_o, compute_rx_o_o, compute_rc_o_i, compute_ry_o_i, compute_rx_o_i, compute_nn_o_i, compute_ff_o_i, compute_yy_o_i, compute_xx_o_i, compute_rc_i, compute_ry_i, compute_rx_i, compute_nn_i, compute_ff_i, compute_yy_i, compute_xx_i)
# compute_i0_o_i, compute_i0_i = s[compute].split(compute_i0, factor=1)
# compute_i0_o_o_i, compute_i0_o_i = s[compute].split(compute_i0_o_i, factor=1)
# compute_i0_o_o_o, compute_i0_o_o_i = s[compute].split(compute_i0_o_o_i, factor=1)
# compute_i1_o_i, compute_i1_i = s[compute].split(compute_i1, factor=1)
# compute_i1_o_o_i, compute_i1_o_i = s[compute].split(compute_i1_o_i, factor=4)
# compute_i1_o_o_o, compute_i1_o_o_i = s[compute].split(compute_i1_o_o_i, factor=8)
# compute_i2_o_i, compute_i2_i = s[compute].split(compute_i2, factor=1)
# compute_i2_o_o_i, compute_i2_o_i = s[compute].split(compute_i2_o_i, factor=7)
# compute_i2_o_o_o, compute_i2_o_o_i = s[compute].split(compute_i2_o_o_i, factor=1)
# compute_i3_o_i, compute_i3_i = s[compute].split(compute_i3, factor=1)
# compute_i3_o_o_i, compute_i3_o_i = s[compute].split(compute_i3_o_i, factor=7)
# compute_i3_o_o_o, compute_i3_o_o_i = s[compute].split(compute_i3_o_o_i, factor=1)
# s[compute].reorder(compute_i0_o_o_o, compute_i1_o_o_o, compute_i2_o_o_o, compute_i3_o_o_o, compute_i0_o_o_i, compute_i1_o_o_i, compute_i2_o_o_i, compute_i3_o_o_i, compute_i0_o_i, compute_i1_o_i, compute_i2_o_i, compute_i3_o_i, compute_i0_i, compute_i1_i, compute_i2_i, compute_i3_i)
# s[compute].compute_at(s[compute], compute_i3_o_i)
# kernel_shared = s.cache_read(kernel, "shared", [compute])
# kernel_shared_ax0, kernel_shared_ax1, kernel_shared_ax2, kernel_shared_ax3 = tuple(kernel_shared.op.axis)
# s[kernel_shared].compute_at(s[compute], compute_rx_o_o)
# pad_temp_shared = s.cache_read(pad_temp, "shared", [compute])
# pad_temp_shared_ax0, pad_temp_shared_ax1, pad_temp_shared_ax2, pad_temp_shared_ax3 = tuple(pad_temp_shared.op.axis)
# s[pad_temp_shared].compute_at(s[compute], compute_rx_o_o)
# s[pad_temp].compute_inline()
# compute_i0_o_o_o_i1_o_o_o_fused_i2_o_o_o_fused_i3_o_o_o_fused = s[compute].fuse(compute_i0_o_o_o, compute_i1_o_o_o, compute_i2_o_o_o, compute_i3_o_o_o)
# s[compute].bind(compute_i0_o_o_o_i1_o_o_o_fused_i2_o_o_o_fused_i3_o_o_o_fused, te.thread_axis("blockIdx.x"))
# compute_i0_o_o_i_i1_o_o_i_fused_i2_o_o_i_fused_i3_o_o_i_fused = s[compute].fuse(compute_i0_o_o_i, compute_i1_o_o_i, compute_i2_o_o_i, compute_i3_o_o_i)
# s[compute].bind(compute_i0_o_o_i_i1_o_o_i_fused_i2_o_o_i_fused_i3_o_o_i_fused, te.thread_axis("vthread"))
# compute_i0_o_i_i1_o_i_fused_i2_o_i_fused_i3_o_i_fused = s[compute].fuse(compute_i0_o_i, compute_i1_o_i, compute_i2_o_i, compute_i3_o_i)
# s[compute].bind(compute_i0_o_i_i1_o_i_fused_i2_o_i_fused_i3_o_i_fused, te.thread_axis("threadIdx.x"))
# kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused = s[kernel_shared].fuse(kernel_shared_ax0, kernel_shared_ax1, kernel_shared_ax2, kernel_shared_ax3)
# kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i = s[kernel_shared].split(kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused, factor=1)
# s[kernel_shared].vectorize(kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i)
# kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_o, kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i = s[kernel_shared].split(kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, factor=196)
# s[kernel_shared].bind(kernel_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i, te.thread_axis("threadIdx.x"))
# pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused = s[pad_temp_shared].fuse(pad_temp_shared_ax0, pad_temp_shared_ax1, pad_temp_shared_ax2, pad_temp_shared_ax3)
# pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i = s[pad_temp_shared].split(pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused, factor=4)
# s[pad_temp_shared].vectorize(pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_i)
# pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_o, pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i = s[pad_temp_shared].split(pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o, factor=196)
# s[pad_temp_shared].bind(pad_temp_shared_ax0_ax1_fused_ax2_fused_ax3_fused_o_i, te.thread_axis("threadIdx.x"))
# s[compute].pragma(compute_nn_o_o_o_o, "auto_unroll_max_step", 1024)
# s[compute].pragma(compute_nn_o_o_o_o, "unroll_explicit", True)
#
# CUDA source code:
#
# #ifdef _WIN32
#   using uint = unsigned int;
#   using uchar = unsigned char;
#   using ushort = unsigned short;
#   using int64_t = long long;
#   using uint64_t = unsigned long long;
# #else
#   #define uint unsigned int
#   #define uchar unsigned char
#   #define ushort unsigned short
#   #define int64_t long long
#   #define uint64_t unsigned long long
# #endif
# extern "C" __global__ void __launch_bounds__(196) default_function_kernel0(float* __restrict__ data, float* __restrict__ kernel, float* __restrict__ compute, float* __restrict__ bias) {
#   float compute1[8];
#   __shared__ float pad_temp_shared[1008];
#   __shared__ float kernel_shared[1536];
#   compute1[(0)] = 0.000000e+00f;
#   compute1[(1)] = 0.000000e+00f;
#   compute1[(2)] = 0.000000e+00f;
#   compute1[(3)] = 0.000000e+00f;
#   compute1[(4)] = 0.000000e+00f;
#   compute1[(5)] = 0.000000e+00f;
#   compute1[(6)] = 0.000000e+00f;
#   compute1[(7)] = 0.000000e+00f;
#   for (int rc_outer_outer = 0; rc_outer_outer < 32; ++rc_outer_outer) {
#     for (int ry_outer_outer = 0; ry_outer_outer < 3; ++ry_outer_outer) {
#       __syncthreads();
#       pad_temp_shared[((((int)threadIdx.x) * 4))] = (((((1 <= ((((((int)threadIdx.x) * 4) % 63) / 9) + ry_outer_outer)) && (((((((int)threadIdx.x) * 4) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= ((((int)threadIdx.x) * 4) % 9))) && (((((int)threadIdx.x) * 4) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + (((((int)threadIdx.x) * 4) / 9) * 7)) + (ry_outer_outer * 7)) + ((((int)threadIdx.x) * 4) % 9)) - 8))] : 0.000000e+00f);
#       pad_temp_shared[(((((int)threadIdx.x) * 4) + 1))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 1) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 1) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 1) % 9))) && ((((((int)threadIdx.x) * 4) + 1) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 1) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 1) % 9)) - 8))] : 0.000000e+00f);
#       pad_temp_shared[(((((int)threadIdx.x) * 4) + 2))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 2) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 2) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 2) % 9))) && ((((((int)threadIdx.x) * 4) + 2) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 2) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 2) % 9)) - 8))] : 0.000000e+00f);
#       pad_temp_shared[(((((int)threadIdx.x) * 4) + 3))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 3) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 3) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 3) % 9))) && ((((((int)threadIdx.x) * 4) + 3) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 3) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 3) % 9)) - 8))] : 0.000000e+00f);
#       if (((int)threadIdx.x) < 56) {
#         pad_temp_shared[(((((int)threadIdx.x) * 4) + 784))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 28) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 28) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 1) % 9))) && ((((((int)threadIdx.x) * 4) + 1) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 784) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 1) % 9)) - 8))] : 0.000000e+00f);
#       }
#       if (((int)threadIdx.x) < 56) {
#         pad_temp_shared[(((((int)threadIdx.x) * 4) + 785))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 29) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 29) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 2) % 9))) && ((((((int)threadIdx.x) * 4) + 2) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 785) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 2) % 9)) - 8))] : 0.000000e+00f);
#       }
#       if (((int)threadIdx.x) < 56) {
#         pad_temp_shared[(((((int)threadIdx.x) * 4) + 786))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 30) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 30) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 3) % 9))) && ((((((int)threadIdx.x) * 4) + 3) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 786) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 3) % 9)) - 8))] : 0.000000e+00f);
#       }
#       if (((int)threadIdx.x) < 56) {
#         pad_temp_shared[(((((int)threadIdx.x) * 4) + 787))] = (((((1 <= (((((((int)threadIdx.x) * 4) + 31) % 63) / 9) + ry_outer_outer)) && ((((((((int)threadIdx.x) * 4) + 31) % 63) / 9) + ry_outer_outer) < 8)) && (1 <= (((((int)threadIdx.x) * 4) + 4) % 9))) && ((((((int)threadIdx.x) * 4) + 4) % 9) < 8)) ? data[((((((rc_outer_outer * 784) + ((((((int)threadIdx.x) * 4) + 787) / 9) * 7)) + (ry_outer_outer * 7)) + (((((int)threadIdx.x) * 4) + 4) % 9)) - 8))] : 0.000000e+00f);
#       }
#       kernel_shared[(((int)threadIdx.x))] = kernel[(((((((((int)blockIdx.x) * 147456) + ((((int)threadIdx.x) / 48) * 4608)) + (rc_outer_outer * 144)) + (((((int)threadIdx.x) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + (((int)threadIdx.x) % 3)))];
#       kernel_shared[((((int)threadIdx.x) + 196))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 196) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 4) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + ((((int)threadIdx.x) + 1) % 3)))];
#       kernel_shared[((((int)threadIdx.x) + 392))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 392) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 8) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + ((((int)threadIdx.x) + 2) % 3)))];
#       kernel_shared[((((int)threadIdx.x) + 588))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 588) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 12) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + (((int)threadIdx.x) % 3)))];
#       kernel_shared[((((int)threadIdx.x) + 784))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 784) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 16) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + ((((int)threadIdx.x) + 1) % 3)))];
#       kernel_shared[((((int)threadIdx.x) + 980))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 980) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 20) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + ((((int)threadIdx.x) + 2) % 3)))];
#       kernel_shared[((((int)threadIdx.x) + 1176))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 1176) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 24) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + (((int)threadIdx.x) % 3)))];
#       if (((int)threadIdx.x) < 164) {
#         kernel_shared[((((int)threadIdx.x) + 1372))] = kernel[(((((((((int)blockIdx.x) * 147456) + (((((int)threadIdx.x) + 1372) / 48) * 4608)) + (rc_outer_outer * 144)) + ((((((int)threadIdx.x) + 28) % 48) / 3) * 9)) + (ry_outer_outer * 3)) + ((((int)threadIdx.x) + 1) % 3)))];
#       }
#       __syncthreads();
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[(((((int)threadIdx.x) / 49) * 48))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 192))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 384))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 576))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 768))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 960))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1152))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[(((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1344))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 193))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 385))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 577))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 769))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 961))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1153))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 1))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1345))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 2))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 194))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 386))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 578))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 770))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 962))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1154))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 2))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1346))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 3))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 195))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 387))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 579))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 771))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 963))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1155))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 63))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1347))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 4))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 196))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 388))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 580))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 772))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 964))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1156))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 64))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1348))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 5))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 197))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 389))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 581))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 773))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 965))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1157))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 65))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1349))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 6))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 198))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 390))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 582))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 774))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 966))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1158))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 126))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1350))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 7))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 199))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 391))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 583))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 775))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 967))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1159))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 127))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1351))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 8))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 200))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 392))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 584))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 776))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 968))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1160))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 128))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1352))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 9))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 201))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 393))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 585))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 777))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 969))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1161))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 189))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1353))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 10))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 202))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 394))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 586))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 778))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 970))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1162))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 190))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1354))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 11))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 203))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 395))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 587))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 779))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 971))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1163))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 191))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1355))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 12))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 204))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 396))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 588))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 780))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 972))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1164))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 252))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1356))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 13))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 205))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 397))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 589))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 781))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 973))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1165))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 253))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1357))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 14))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 206))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 398))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 590))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 782))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 974))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1166))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 254))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1358))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 15))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 207))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 399))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 591))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 783))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 975))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1167))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 315))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1359))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 16))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 208))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 400))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 592))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 784))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 976))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1168))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 316))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1360))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 17))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 209))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 401))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 593))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 785))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 977))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1169))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 317))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1361))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 18))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 210))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 402))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 594))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 786))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 978))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1170))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 378))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1362))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 19))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 211))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 403))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 595))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 787))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 979))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1171))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 379))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1363))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 20))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 212))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 404))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 596))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 788))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 980))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1172))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 380))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1364))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 441))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 21))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 441))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 213))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 441))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 405))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 441))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 597))]));
# ...
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 758))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1382))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 39))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 231))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 423))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 615))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 807))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 999))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1191))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 819))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1383))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 40))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 232))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 424))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 616))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 808))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1000))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1192))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 820))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1384))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 41))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 233))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 425))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 617))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 809))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1001))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1193))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 821))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1385))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 42))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 234))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 426))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 618))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 810))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1002))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1194))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 882))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1386))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 43))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 235))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 427))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 619))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 811))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1003))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1195))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 883))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1387))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 44))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 236))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 428))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 620))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 812))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1004))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1196))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 884))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1388))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 45))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 237))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 429))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 621))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 813))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1005))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1197))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 945))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1389))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 46))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 238))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 430))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 622))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 814))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1006))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1198))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 946))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1390))]));
#       compute1[(0)] = (compute1[(0)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 47))]));
#       compute1[(1)] = (compute1[(1)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 239))]));
#       compute1[(2)] = (compute1[(2)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 431))]));
#       compute1[(3)] = (compute1[(3)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 623))]));
#       compute1[(4)] = (compute1[(4)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 815))]));
#       compute1[(5)] = (compute1[(5)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1007))]));
#       compute1[(6)] = (compute1[(6)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1199))]));
#       compute1[(7)] = (compute1[(7)] + (pad_temp_shared[((((((((int)threadIdx.x) % 49) / 7) * 9) + (((int)threadIdx.x) % 7)) + 947))] * kernel_shared[((((((int)threadIdx.x) / 49) * 48) + 1391))]));
#     }
#   }
#   compute[(((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)))] = max((compute1[(0)] + bias[(((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 196))] = max((compute1[(1)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 4))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 392))] = max((compute1[(2)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 8))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 588))] = max((compute1[(3)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 12))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 784))] = max((compute1[(4)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 16))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 980))] = max((compute1[(5)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 20))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 1176))] = max((compute1[(6)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 24))]), 0.000000e+00f);
#   compute[((((((int)blockIdx.x) * 1568) + ((int)threadIdx.x)) + 1372))] = max((compute1[(7)] + bias[((((((int)blockIdx.x) * 32) + (((int)threadIdx.x) / 49)) + 28))]), 0.000000e+00f);
# }

# %% [markdown]
# A more complicated example is to resume the search. In this case, we need to create the search policy and cost model by ourselves and resume the status of search policy and cost model with the log file. In the example below we resume the status and do more 5 trials.

# %%
def resume_search(task, log_file):
    print("Resume search:")
    cost_model = auto_scheduler.XGBModel()
    cost_model.update_from_file(log_file)
    search_policy = auto_scheduler.SketchPolicy(
        task, cost_model, init_search_callbacks=[auto_scheduler.PreloadMeasuredStates(log_file)]
    )
    measure_ctx = auto_scheduler.LocalRPCMeasureContext(min_repeat_ms=300)
    tune_option = auto_scheduler.TuningOptions(
        num_measure_trials=5,
        runner=measure_ctx.runner,
        measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    )
    task.tune(tune_option, search_policy=search_policy)

    # Kill the measurement process
    del measure_ctx


resume_search(task, log_file)
# Out:
# Resume search:
# Get devices for measurement successfully!
